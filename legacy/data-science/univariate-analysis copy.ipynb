# %%
import pandas as pd
df = pd.read_csv('../data/gold/schengen-visa.csv')
pd.options.display.float_format = '{:,.2f}'.format

# %%
df['visas_applied'] = df['visas_applied'].astype('int')
df['visas_issued'] = df['visas_issued'].astype('int')
df['visas_not_issued'] = df['visas_not_issued'].astype('int')
df['year'] = df['year'].astype('str')
df['date'] = pd.to_datetime(df['year'], format='%Y')

# %%
df[df['schengen_state'] == 'Denmark'].groupby(['year'])['visa_refusal_rate'].mean().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Denmark'].groupby(['year'])['visa_refusal_rate'].mean().pct_change().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Germany'].groupby(['year'])['visa_refusal_rate'].mean().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Germany'].groupby(['year'])['visa_refusal_rate'].mean().pct_change().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'France'].groupby(['year'])['visa_refusal_rate'].mean().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Spain'].groupby(['year'])['visa_refusal_rate'].mean().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Italy'].groupby(['year'])['visa_refusal_rate'].mean().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Poland'].groupby(['year'])['visa_refusal_rate'].mean().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Sweden'].groupby(['year'])['visa_refusal_rate'].mean().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Norway'].groupby(['year'])['visa_refusal_rate'].mean().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Netherlands'].groupby(['year'])['visa_refusal_rate'].mean().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Netherlands'].groupby(['year'])['visa_refusal_rate'].mean().pct_change().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Italy'].groupby(['year'])['visa_refusal_rate'].mean().pct_change().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Belgium'].groupby(['year'])['visa_refusal_rate'].mean().pct_change().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['schengen_state'] == 'Germany'].groupby(['year'])['visa_refusal_rate'].mean().pct_change()
# Out:
# year
# 2005     NaN
# 2006    0.22
# 2007   -0.12
# 2008   -0.12
# 2009   -0.00
# 2010    0.04
# 2011    0.09
# 2012   -0.06
# 2013    0.13
# 2014   -0.32
# 2015   -0.12
# 2016    0.08
# 2017    0.16
# 2018    0.05
# 2019    0.19
# 2020    0.27
# 2021   -0.12
# 2022    0.01
# Name: visa_refusal_rate, dtype: float64

# %%
df.pivot_table(
    values="visa_refusal_rate", index="schengen_state", columns="year", aggfunc="mean"
)
# Out:
# year            2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  \
# schengen_state
# Austria         0.05  0.05  0.00  0.00  0.07  0.07  0.10  0.07  0.05  0.04
# Belgium         0.17  0.17  0.16  0.17  0.16  0.18  0.22  0.26  0.13  0.17
# Bulgaria         NaN  0.13  0.10  0.08  0.06  0.07  0.07   NaN   NaN   NaN
# Cyprus          0.05  0.03  0.04  0.08  0.07  0.07   NaN   NaN   NaN   NaN
# Czech Republic  0.05  0.06  0.08  0.17  0.10  0.14  0.17  0.11  0.18  0.10
# Denmark         0.15  0.15  0.13  0.21  0.12  0.16  0.09  0.13  0.13  0.09
# Estonia         0.09  0.05  0.05  0.16  0.09  0.11  0.10  0.07  0.15  0.05
# Finland         0.12  0.13  0.15  0.14  0.20  0.18  0.16  0.24  0.14  0.16
# France          0.14  0.17  0.16  0.10  0.17  0.09  0.08  0.09  0.09  0.09
# Germany         0.12  0.15  0.13  0.11  0.11  0.12  0.13  0.12  0.14  0.09
# Greece          0.00  0.10  0.07  0.07  0.07  0.05  0.05  0.05  0.05  0.06
# ...

# %%
df.pivot_table(
    values="visa_refusal_rate", index="year", columns="schengen_state", aggfunc="mean"
).plot.line(figsize=(20,100),subplots=True)
# Out:
# array([<AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>],
#       dtype=object)

# %%
df.plot.scatter(x='visa_refusal_rate',y='visas_applied',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='visa_refusal_rate', ylabel='visas_applied'>
