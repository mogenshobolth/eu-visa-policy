# %% [markdown]
# Clean-up raw Schengen input file and save as silver statistics

# %%
import schengentools.visastatsparser as vp
job = vp.Parser(2016)
job.extract('../data/bronze/2016_consulates_schengen_visa_stats_en.xlsx')
job.transform()
job.load()
df = job.df
# Out:
# Input file loaded into dataframe
# Renamed columns
# Removed irrelevant rows such as summary rows
# Selected columns
# Replaced applied, issued and not issued null values with 0
# Calculate refusal rate as the not issued share of the total issued and not issued
# Added column with year issued and not issued
# C:\Users\mogens.hobolth\Miniconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %% [markdown]
# Data quality checks

# %%
df[df["visas_applied"] != df["visas_issued"] + df["visas_not_issued"]]
# Out:
#      schengen_state          origin_country   origin_consulate  visas_applied  \
# 1           Austria                 ALGERIA            ALGIERS         1961.0
# 3           Austria               AUSTRALIA           CANBERRA         1942.0
# 5           Austria  BOSNIA AND HERZEGOVINA           SARAJEVO           89.0
# 6           Austria                  BRAZIL           BRASILIA           24.0
# 7           Austria                BULGARIA              SOFIA          236.0
# ...             ...                     ...                ...            ...
# 1874    Switzerland          UNITED KINGDOM             LONDON        10294.0
# 1876    Switzerland                     USA       NEW YORK, NY         2763.0
# 1877    Switzerland                     USA  SAN FRANCISCO, CA         2839.0
# 1878    Switzerland                     USA     WASHINGTON, DC          899.0
# 1879    Switzerland                 VIETNAM        HO CHI MINH         2642.0
#
#       visas_issued  visas_not_issued  visa_refusal_rate  year
# 1           1478.0             472.0           0.242051  2016
# 3           1927.0              11.0           0.005676  2016
# 5             82.0               2.0           0.023810  2016
# 6             23.0               0.0           0.000000  2016
# 7            225.0               9.0           0.038462  2016
# ...            ...               ...                ...   ...
# 1874       10049.0             192.0           0.018748  2016
# 1876        2686.0               8.0           0.002970  2016
# 1877        2820.0               8.0           0.002829  2016
# 1878         859.0              13.0           0.014908  2016
# 1879        2473.0             155.0           0.058980  2016
#
# [1355 rows x 8 columns]

# %%
df[df["visa_refusal_rate"]>1]
# Out:
# Empty DataFrame
# Columns: [schengen_state, origin_country, origin_consulate, visas_applied, visas_issued, visas_not_issued, visa_refusal_rate, year]
# Index: []

# %%
df[df["visa_refusal_rate"].isna()]
# Out:
#      schengen_state               origin_country origin_consulate  \
# 64          Belgium                      AUSTRIA           VIENNA
# 309         Finland                      AUSTRIA           VIENNA
# 310         Finland                      BELGIUM         BRUSSELS
# 312         Finland                       CANADA           OTTAWA
# 339         Finland                       NORWAY             OSLO
# 351         Finland                        SPAIN           MADRID
# 362         Finland                       ZAMBIA           LUSAKA
# 594         Germany                      ESTONIA          TALLINN
# 1078      Lithuania                       GREECE           ATHENS
# 1178    Netherlands               CZECH REPUBLIC           PRAGUE
# 1288         Norway                     ETHIOPIA      ADDIS ABEBA
# 1370         Poland                      HUNGARY         BUDAPEST
# 1409         Poland                       SWEDEN        STOCKHOLM
