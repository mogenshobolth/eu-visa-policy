# %% [markdown]
# Clean-up raw Schengen input file and save as silver statistics

# %%
import schengentools.visastatsparser as vp
job = vp.Parser(2019)
job.extract('../data/bronze/2019-consulates-schengen-visa-stats.xlsx')
job.transform()
job.load()
df = job.df
# Out:
# Input file loaded into dataframe
# Renamed columns
# Removed irrelevant rows such as summary rows
# Selected columns
# Replaced applied, issued and not issued null values with 0
# Calculate refusal rate as the not issued share of the total issued and not issued
# Added column with year issued and not issued
# C:\Users\mogens.hobolth\Miniconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %% [markdown]
# Data quality checks

# %%
df[df["visas_applied"] != df["visas_issued"] + df["visas_not_issued"]]
# Out:
#      schengen_state origin_country   origin_consulate  visas_applied  \
# 3           Austria      AUSTRALIA           CANBERRA         3271.0
# 10          Austria          CHINA            BEIJING        46670.0
# 17          Austria       ETHIOPIA        ADDIS ABEBA          828.0
# 20          Austria          INDIA          NEW DELHI        36488.0
# 22          Austria           IRAN            TEHERAN         5230.0
# ...             ...            ...                ...            ...
# 1828    Switzerland            USA        ATLANTA, GA         1795.0
# 1829    Switzerland            USA       NEW YORK, NY         3745.0
# 1830    Switzerland            USA  SAN FRANCISCO, CA         4599.0
# 1831    Switzerland            USA     WASHINGTON, DC         1173.0
# 1833    Switzerland        VIETNAM        HO CHI MINH         4142.0
#
#       visas_issued  visas_not_issued  visa_refusal_rate  year
# 3           3213.0              56.0           0.017131  2019
# 10         45599.0            1072.0           0.022969  2019
# 17           804.0              23.0           0.027811  2019
# 20         34287.0            2199.0           0.060270  2019
# 22          4288.0             941.0           0.179958  2019
# ...            ...               ...                ...   ...
# 1828        1784.0               8.0           0.004464  2019
# 1829        3629.0              34.0           0.009282  2019
# 1830        4555.0              32.0           0.006976  2019
# 1831        1139.0              24.0           0.020636  2019
# 1833        3820.0             314.0           0.075955  2019
#
# [1255 rows x 8 columns]

# %%
df[df["visa_refusal_rate"]>1]
# Out:
# Empty DataFrame
# Columns: [schengen_state, origin_country, origin_consulate, visas_applied, visas_issued, visas_not_issued, visa_refusal_rate, year]
# Index: []

# %%
df[df["visa_refusal_rate"].isna()]
# Out:
#      schengen_state               origin_country origin_consulate  \
# 313         Finland                      GERMANY           BERLIN
# 323         Finland                    LITHUANIA          VILNIUS
# 344         Finland                       SWEDEN        STOCKHOLM
# 471          France                       POLAND           WARSAW
# 523         Germany                      BELGIUM         BRUSSELS
# 557         Germany                      FINLAND         HELSINKI
# 686          Greece                      AUSTRIA           VIENNA
# 792         Hungary                       GREECE           ATHENS
# 899           Italy                      DENMARK       COPENHAGEN
# 1050      Lithuania                        ITALY             ROME
# 1121    Netherlands                      ALBANIA           TIRANA
# 1141    Netherlands  CONGO (DEMOCRATIC REPUBLIC)         KINSHASA
