# %% [markdown]
# Clean-up raw Schengen input file and save as silver statistics

# %%
import schengentools.visastatsparser as vp
job = vp.Parser(2021)
job.extract('../data/bronze/Visa statistics for consulates 2021_0.xlsx')
job.transform()
job.load()
df = job.df
# Out:
# Input file loaded into dataframe
# Renamed columns
# Removed irrelevant rows such as summary rows
# Selected columns
# Replaced applied, issued and not issued null values with 0
# Calculate refusal rate as the not issued share of the total issued and not issued
# Added column with year issued and not issued
# /Users/hobolthwagner/opt/anaconda3/lib/python3.8/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %% [markdown]
# Data quality checks

# %%
df[df["visas_applied"] != df["visas_issued"] + df["visas_not_issued"]]
# Out:
#      schengen_state  origin_country   origin_consulate  visas_applied  \
# 0           Austria         ALBANIA             TIRANA           32.0
# 7           Austria        BULGARIA              SOFIA          227.0
# 13          Austria         CROATIA             ZAGREB          216.0
# 15          Austria          CYPRUS            NICOSIA          671.0
# 18          Austria         GERMANY             MUNICH          133.0
# ...             ...             ...                ...            ...
# 1677    Switzerland  UNITED KINGDOM             LONDON         1715.0
# 1679    Switzerland             USA       NEW YORK, NY          812.0
# 1680    Switzerland             USA  SAN FRANCISCO, CA          764.0
# 1681    Switzerland             USA     WASHINGTON, DC          275.0
# 1683    Switzerland         VIETNAM        HO CHI MINH          158.0
#
#       visas_issued  visas_not_issued  visa_refusal_rate  year
# 0             23.0               7.0           0.233333  2021
# 7            221.0               4.0           0.017778  2021
# 13           170.0              31.0           0.154229  2021
# 15           655.0              11.0           0.016517  2021
# 18           120.0              12.0           0.090909  2021
# ...            ...               ...                ...   ...
# 1677        1675.0              28.0           0.016442  2021
# 1679         782.0              10.0           0.012626  2021
# 1680         757.0               4.0           0.005256  2021
# 1681         271.0               1.0           0.003676  2021
# 1683         107.0               0.0           0.000000  2021
#
# [1124 rows x 8 columns]

# %%
df[df["visa_refusal_rate"]>1]
# Out:
# Empty DataFrame
# Columns: [schengen_state, origin_country, origin_consulate, visas_applied, visas_issued, visas_not_issued, visa_refusal_rate, year]
# Index: []

# %%
df[df["visa_refusal_rate"].isna()]
# Out:
#      schengen_state                 origin_country origin_consulate  \
# 86          Belgium                         GREECE           ATHENS
# 124         Belgium                   SOUTH AFRICA     JOHANNESBURG
# 259         Denmark                        UKRAINE             KYIV
# 283         Finland                      ARGENTINA     BUENOS AIRES
# 302         Finland                      LITHUANIA          VILNIUS
# 384          France                         FRANCE            PARIS
# 515         Germany                 CZECH REPUBLIC           PRAGUE
# 521         Germany                        ESTONIA          TALLINN
# 634         Germany                      VENEZUELA          CARACAS
