# %% [markdown]
# Clean-up raw Schengen input file and save as silver statistics

# %%
import schengentools.visastatsparser as vp
job = vp.Parser(2015)
job.extract('../data/bronze/2015_consulates_schengen_visa_stats_en.xlsx')
job.transform()
job.load()
df = job.df
# Out:
# Input file loaded into dataframe
# Renamed columns
# Removed irrelevant rows such as summary rows
# Selected columns
# Replaced applied, issued and not issued null values with 0
# Calculate refusal rate as the not issued share of the total issued and not issued
# Added column with year issued and not issued
# C:\Users\mogens.hobolth\Miniconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %% [markdown]
# Data quality checks

# %%
df[df["visas_applied"] != df["visas_issued"] + df["visas_not_issued"]]
# Out:
#      schengen_state          origin_country   origin_consulate  visas_applied  \
# 0           Austria                 ALBANIA             TIRANA           30.0
# 1           Austria                 ALGERIA            ALGIERS         2504.0
# 3           Austria               AUSTRALIA           CANBERRA         2074.0
# 6           Austria  BOSNIA AND HERZEGOVINA           SARAJEVO           74.0
# 8           Austria                BULGARIA              SOFIA          257.0
# ...             ...                     ...                ...            ...
# 1936    Switzerland                     USA  SAN FRANCISCO, CA         2241.0
# 1937    Switzerland                     USA     WASHINGTON, DC          841.0
# 1938    Switzerland              UZBEKISTAN           TASHKENT          585.0
# 1940    Switzerland                 VIETNAM              HANOI          950.0
# 1941    Switzerland                 VIETNAM        HO CHI MINH         1204.0
#
#       visas_issued  visas_not_issued  visa_refusal_rate  year
# 0             20.0               1.0           0.047619  2015
# 1           2212.0             290.0           0.115907  2015
# 3           1983.0              74.0           0.035975  2015
# 6             68.0               5.0           0.068493  2015
# 8            247.0               6.0           0.023715  2015
# ...            ...               ...                ...   ...
# 1936        2222.0              10.0           0.004480  2015
# 1937         796.0              11.0           0.013631  2015
# 1938         570.0              12.0           0.020619  2015
# 1940         865.0              84.0           0.088514  2015
# 1941        1130.0              71.0           0.059117  2015
#
# [1384 rows x 8 columns]

# %%
df[df["visa_refusal_rate"]>1]
# Out:
# Empty DataFrame
# Columns: [schengen_state, origin_country, origin_consulate, visas_applied, visas_issued, visas_not_issued, visa_refusal_rate, year]
# Index: []

# %%
df[df["visa_refusal_rate"].isna()]
# Out:
#      schengen_state       origin_country origin_consulate  visas_applied  \
# 242         Denmark              ALGERIA          ALGIERS            1.0
# 261         Denmark               GREECE           ATHENS            1.0
# 328         Finland              AUSTRIA           VIENNA            1.0
# 338         Finland               GREECE           ATHENS            2.0
# 357         Finland               NORWAY             OSLO           46.0
# 359         Finland               POLAND           WARSAW            1.0
# 360         Finland             PORTUGAL           LISBON            2.0
# 370         Finland                SPAIN           MADRID           17.0
# 371         Finland               SWEDEN        STOCKHOLM            7.0
# 383         Finland               ZAMBIA           LUSAKA            1.0
# 551          France  TRINIDAD AND TOBAGO    PORT OF SPAIN            1.0
# 592         Germany              BELGIUM         BRUSSELS            5.0
# 800          Greece               LATVIA             RIGA            0.0
# 1166          Malta               FRANCE            PARIS            2.0
# 1238    Netherlands                ITALY             ROME           16.0
# 1269    Netherlands               RWANDA           KIGALI            1.0
# 1443         Poland          NETHERLANDS        THE HAGUE            1.0
# 1525       Portugal                ITALY             ROME            1.0
# 1578       Slovakia       CZECH REPUBLIC           PRAGUE            1.0
# 1677          Spain              DENMARK       COPENHAGEN            1.0
# 1690          Spain               FRANCE         BORDEAUX            1.0
# 1697          Spain              GERMANY       DUSSELDORF            9.0
# 1699          Spain              GERMANY          HAMBURG           17.0
# 1700          Spain              GERMANY           MUNICH           24.0
# 1718          Spain                ITALY           NAPLES            2.0
# 1726          Spain               LATVIA             RIGA            5.0
# 1728          Spain           LUXEMBOURG        LUXEMBURG            1.0
# 1750          Spain               NORWAY             OSLO            1.0
# 1769          Spain             SLOVENIA        LJUBLJANA            1.0
# 1774          Spain               SWEDEN        STOCKHOLM            1.0
# 1801         Sweden              ALGERIA          ALGIERS            1.0
# 1813         Sweden               FRANCE            PARIS            8.0
# 1814         Sweden              GERMANY           BERLIN           10.0
# 1815         Sweden               GREECE           ATHENS            7.0
# 1823         Sweden                ITALY             ROME           11.0
# 1837         Sweden                SPAIN           MADRID            6.0
#
#       visas_issued  visas_not_issued  visa_refusal_rate  year
# 242            0.0               0.0                NaN  2015
# 261            0.0               0.0                NaN  2015
# 328            0.0               0.0                NaN  2015
# 338            0.0               0.0                NaN  2015
# 357            0.0               0.0                NaN  2015
# 359            0.0               0.0                NaN  2015
# 360            0.0               0.0                NaN  2015
# 370            0.0               0.0                NaN  2015
# 371            0.0               0.0                NaN  2015
# 383            0.0               0.0                NaN  2015
# 551            0.0               0.0                NaN  2015
# 592            0.0               0.0                NaN  2015
# 800            0.0               0.0                NaN  2015
# 1166           0.0               0.0                NaN  2015
# 1238           0.0               0.0                NaN  2015
# 1269           0.0               0.0                NaN  2015
# 1443           0.0               0.0                NaN  2015
# 1525           0.0               0.0                NaN  2015
# 1578           0.0               0.0                NaN  2015
# 1677           0.0               0.0                NaN  2015
# 1690           0.0               0.0                NaN  2015
# 1697           0.0               0.0                NaN  2015
# 1699           0.0               0.0                NaN  2015
# 1700           0.0               0.0                NaN  2015
# 1718           0.0               0.0                NaN  2015
# 1726           0.0               0.0                NaN  2015
# 1728           0.0               0.0                NaN  2015
# 1750           0.0               0.0                NaN  2015
# 1769           0.0               0.0                NaN  2015
# 1774           0.0               0.0                NaN  2015
# 1801           0.0               0.0                NaN  2015
# 1813           0.0               0.0                NaN  2015
# 1814           0.0               0.0                NaN  2015
# 1815           0.0               0.0                NaN  2015
# 1823           0.0               0.0                NaN  2015
# 1837           0.0               0.0                NaN  2015

# %%
df.describe()
# Out:
#        visas_applied   visas_issued  visas_not_issued  visa_refusal_rate  \
# count    1942.000000    1942.000000       1942.000000        1906.000000
# mean     7954.004119    7367.864058        494.155510           0.088816
# std     30064.444858   28929.967474       2322.196759           0.144305
# min         0.000000       0.000000          0.000000           0.000000
# 25%        49.250000      41.000000          1.000000           0.003132
# 50%       785.000000     625.500000         24.000000           0.031893
# 75%      4304.000000    3546.250000        290.750000           0.108949
# max    567584.000000  562882.000000      70144.000000           1.000000
#
#          year
# count  1942.0
# mean   2015.0
# std       0.0
# min    2015.0
# 25%    2015.0
# 50%    2015.0
# 75%    2015.0
# max    2015.0
