# %%
import pandas as pd
import numpy as np
df = pd.read_excel('../data/bronze/2018-consulates-schengen-visa-stats.xlsx',1)
# Out:
# C:\Users\mogens.hobolth\Miniconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df = df.rename(columns = {"Schengen State": "eu_state"
                         ,"Country where consulate is located": "origin_country"
                         ,"Consulate": "origin_consulate"
                         ,"Uniform visas applied for": "visas_applied"
                         ,"Total  uniform visas issued (including MEV) \n": "visas_issued"
                         ,"Uniform visas not issued": "visas_not_issued"})
df = df[["eu_state", "origin_country","origin_consulate","visas_applied", "visas_issued", "visas_not_issued"]]

# %%
df[df["eu_state"].isna()]
# Out:
#      eu_state origin_country                      origin_consulate  \
# 1900      NaN            NaN                                   NaN
# 1901      NaN            NaN                                   NaN
# 1902      NaN            NaN                                   NaN
# 1903      NaN            NaN                                   NaN
# 1904      NaN            NaN           Selection Sub total in 2018
# 1905      NaN            NaN                  Total worldwide 2018
# 1906      NaN            NaN  Share of subtotal on worldwide total
#
#       visas_applied  visas_issued  visas_not_issued
# 1900            NaN           NaN               NaN
# 1901            NaN           NaN               NaN
# 1902            NaN           NaN               NaN
# 1903            NaN           NaN               NaN
# 1904     16016599.0    14265282.0         1539362.0
# 1905     16016599.0    14265282.0         1539362.0
# 1906            1.0           1.0               1.0

# %%
df = df[df["eu_state"].notna()]

# %%
df["visas_applied"].replace(np.nan, 0, inplace=True)
df["visas_issued"].replace(np.nan, 0, inplace=True)
df["visas_not_issued"].replace(np.nan, 0, inplace=True)
df["visa_refusal_rate"] = df["visas_not_issued"] / (df["visas_issued"] + df["visas_not_issued"])

# %%
df[df["visas_applied"] != df["visas_issued"] + df["visas_not_issued"]]
# Out:
#          eu_state origin_country   origin_consulate  visas_applied  \
# 0         Austria        ALBANIA             TIRANA           62.0
# 1         Austria        ALGERIA            ALGIERS         2481.0
# 3         Austria      AUSTRALIA           CANBERRA         2776.0
# 4         Austria     AZERBAIJAN               BAKU         1976.0
# 7         Austria       BULGARIA              SOFIA          217.0
# ...           ...            ...                ...            ...
# 1894  Switzerland            USA        ATLANTA, GA         1597.0
# 1895  Switzerland            USA       NEW YORK, NY         3561.0
# 1896  Switzerland            USA  SAN FRANCISCO, CA         3642.0
# 1897  Switzerland            USA     WASHINGTON, DC         1066.0
# 1899  Switzerland        VIETNAM        HO CHI MINH         3679.0
#
#       visas_issued  visas_not_issued  visa_refusal_rate
# 0             32.0               9.0           0.219512
# 1           1658.0             822.0           0.331452
# 3           2653.0             122.0           0.043964
# 4           1895.0              79.0           0.040020
# 7            199.0               5.0           0.024510
# ...            ...               ...                ...
# 1894        1592.0               3.0           0.001881
# 1895        3444.0              17.0           0.004912
# 1896        3623.0               6.0           0.001653
# 1897        1022.0              30.0           0.028517
# 1899        3334.0             301.0           0.082806
#
# [1374 rows x 7 columns]

# %%
df[df["visa_refusal_rate"]>1]
# Out:
# Empty DataFrame
# Columns: [eu_state, origin_country, origin_consulate, visas_applied, visas_issued, visas_not_issued, visa_refusal_rate]
# Index: []

# %%
year = 2018
df["year"] = year

# %%
df.to_csv('../data/silver/schengen-visa-' + str(year) + '.csv')

# %%
df.describe()
# Out:
#        visas_applied   visas_issued  visas_not_issued  visa_refusal_rate  \
# count    1900.000000    1900.000000       1900.000000        1867.000000
# mean     8429.788947    7508.043158        810.190526           0.124042
# std     31030.052644   29361.942782       4109.914954           0.170140
# min         0.000000       0.000000          0.000000           0.000000
# 25%        67.500000      50.750000          2.000000           0.009229
# 50%       892.000000     703.500000         38.500000           0.052776
# 75%      4561.000000    3648.250000        470.000000           0.178263
# max    541080.000000  538601.000000     123565.000000           1.000000
#
#          year
# count  1900.0
# mean   2018.0
# std       0.0
# min    2018.0
# 25%    2018.0
# 50%    2018.0
# 75%    2018.0
# max    2018.0
