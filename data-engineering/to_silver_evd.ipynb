# %%
import pandas as pd
df = pd.read_csv('../data/bronze/european_visa_database/visa_practice_eu.csv')
df
# Out:
#        visaPracticeEuID  rcID receivingCountryName receivengCountryCode  \
# 0                 31797   173              Belgium                   BE
# 1                 31798   173              Belgium                   BE
# 2                 31799   173              Belgium                   BE
# 3                 31800   173              Belgium                   BE
# 4                 31801   173              Belgium                   BE
# ...                 ...   ...                  ...                  ...
# 19013             50810   185                Italy                   IT
# 19014             50811   190          Netherlands                   NL
# 19015             50812   170               Norway                   NO
# 19016             50813   192             Portugal                   PT
# 19017             50814   196                Spain                   ES
#
#        scCityID sendingCountryName sendingCountryCode sendingCityName  dYear  \
# 0             7            Algeria                 DZ         Algiers   2005
# 1            11             Angola                 AO          Luanda   2005
# 2            13          Argentina                 AR    Buenos Aires   2005
# 3            21          Australia                 AU        Canberra   2005
# 4           281            Austria                 AT          Vienna   2005
# ...         ...                ...                ...             ...    ...
# 19013       265           Zimbabwe                 ZW          Harare   2012
# 19014       265           Zimbabwe                 ZW          Harare   2012
# 19015       265           Zimbabwe                 ZW          Harare   2012
# 19016       265           Zimbabwe                 ZW          Harare   2012
# 19017       265           Zimbabwe                 ZW          Harare   2012
#
#        shortStayAppliedFor  ...  issuedABCDVTL  issuedABCDDCVTL  appliedA  \
# 0                   5361.0  ...            NaN           4372.0       NaN
# 1                   1910.0  ...            NaN           1140.0       NaN
# 2                     17.0  ...            NaN             75.0       NaN
# 3                    387.0  ...            NaN            253.0       NaN
# 4                      2.0  ...            NaN              9.0       NaN
# ...                    ...  ...            ...              ...       ...
# 19013                669.0  ...            NaN              NaN       0.0
# 19014                391.0  ...            NaN              NaN       NaN
# 19015                596.0  ...            NaN              NaN       0.0
# 19016                136.0  ...            NaN              NaN       NaN
# 19017                293.0  ...            NaN              NaN       NaN
#
#        appliedB  appliedC  appliedABC  notIssuedA  notIssuedB  notIssuedC  \
# 0           NaN    5070.0      5075.0         NaN         NaN         NaN
# 1           NaN    1699.0      1910.0         NaN         NaN         NaN
# 2           NaN      17.0        17.0         NaN         NaN         NaN
# 3           NaN     274.0       387.0         NaN         NaN         NaN
# 4           NaN       2.0         2.0         NaN         NaN         NaN
# ...         ...       ...         ...         ...         ...         ...
# 19013       NaN     665.0       665.0         0.0         NaN         0.0
# 19014       NaN     391.0       391.0         NaN         NaN         NaN
# 19015       NaN     524.0       524.0         0.0         NaN        40.0
# 19016       NaN     136.0       136.0         NaN         NaN         NaN
# 19017       NaN     292.0       292.0         NaN         NaN         2.0
#
#        notIssuedABC
# 0            1340.0
# 1             144.0
# 2               4.0
# 3             273.0
# 4               0.0
# ...             ...
# 19013           NaN
# 19014           NaN
# 19015          40.0
# 19016           NaN
# 19017           2.0
#
# [19018 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['visaPracticeEuID', 'rcID', 'receivingCountryName',
#        'receivengCountryCode', 'scCityID', 'sendingCountryName',
#        'sendingCountryCode', 'sendingCityName', 'dYear', 'shortStayAppliedFor',
#        'shortStayIssued', 'shortStayRefused', 'shortStayRefusalRate',
#        'issuedA_All', 'issuedA_Mev', 'issuedB', 'issuedC_All', 'issuedC_Mev',
#        'issuedD', 'issuedDC', 'issuedVTL', 'issuedADS', 'issuedABC',
#        'issuedABCVTL', 'issuedABCDVTL', 'issuedABCDDCVTL', 'appliedA',
#        'appliedB', 'appliedC', 'appliedABC', 'notIssuedA', 'notIssuedB',
#        'notIssuedC', 'notIssuedABC'],
#       dtype='object')

# %% [markdown]
# Clean-up raw Schengen input file and save as silver statistics

# %%
import numpy as np

column_mapping = {"receivingCountryName": "schengen_state"
                    ,"sendingCountryName": "origin_country"
                    ,"sendingCityName": "origin_consulate"
                    ,"appliedC": "visas_applied"
                    ,"issuedC_All": "visas_issued"
                    ,"notIssuedC": "visas_not_issued"
                    ,"dYear": "year"}

df = df.rename(columns = column_mapping)
print('Renamed columns')

df = df[["schengen_state", "origin_country","origin_consulate","visas_applied", "visas_issued", "visas_not_issued"]]
print('Selected columns')

df["visas_applied"].replace(np.nan, 0, inplace=True)
df["visas_issued"].replace(np.nan, 0, inplace=True)
df["visas_not_issued"].replace(np.nan, 0, inplace=True)
print('Replaced applied, issued and not issued null values with 0')

df["visas_issued"].loc[df["visas_issued"]<0] = 0
print('Replaced negative entries for visas issued with 0')

df["visa_refusal_rate"] = df["visas_not_issued"] / (df["visas_issued"] + df["visas_not_issued"])
print('Calculate refusal rate as the not issued share of the total issued and not issued')

df.to_csv('../data/silver/schengen-visa-evd.csv')
# Out:
# Renamed columns
# Selected columns
# Replaced applied, issued and not issued null values with 0
# Replaced negative entries for visas issued with 0
# Calculate refusal rate as the not issued share of the total issued and not issued
# /var/folders/15/q71mgwyd7jndbh0bd__klkvw0000gn/T/ipykernel_6375/812831928.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["visas_issued"].loc[df["visas_issued"]<0] = 0

# %% [markdown]
# Data quality checks

# %%
df[df["visas_applied"] != df["visas_issued"] + df["visas_not_issued"]]
# Out:
#       schengen_state origin_country origin_consulate  visas_applied  \
# 0            Belgium        Algeria          Algiers         5070.0
# 1            Belgium         Angola           Luanda         1699.0
# 2            Belgium      Argentina     Buenos Aires           17.0
# 3            Belgium      Australia         Canberra          274.0
# 4            Belgium        Austria           Vienna            2.0
# ...              ...            ...              ...            ...
# 19002          Spain          Yemen          Sana 'a          684.0
# 19003        Denmark         Zambia           Lusaka          489.0
# 19008    Netherlands         Zambia           Lusaka          251.0
# 19009         Sweden         Zambia           Lusaka          989.0
# 19017          Spain       Zimbabwe           Harare          292.0
#
#        visas_issued  visas_not_issued  visa_refusal_rate
# 0            3735.0               0.0           0.000000
# 1             944.0               0.0           0.000000
# 2              13.0               0.0           0.000000
# 3             113.0               0.0           0.000000
# 4               3.0               0.0           0.000000
# ...             ...               ...                ...
# 19002         627.0               1.0           0.001592
# 19003         256.0               6.0           0.022901
# 19008         243.0               7.0           0.028000
# 19009         929.0              18.0           0.019007
# 19017         278.0               2.0           0.007143
#
# [13086 rows x 7 columns]

# %%
df[df["visa_refusal_rate"]>1]
# Out:
# Empty DataFrame
# Columns: [schengen_state, origin_country, origin_consulate, visas_applied, visas_issued, visas_not_issued, visa_refusal_rate]
# Index: []

# %%
df[df["visa_refusal_rate"].isna()]
# Out:
#       schengen_state origin_country origin_consulate  visas_applied  \
# 6            Belgium        Bolivia           La Paz            0.0
# 51           Belgium     Luxembourg        Luxemburg            0.0
# 97           Denmark        Austria           Vienna            1.0
# 99           Denmark        Belgium         Brussels            1.0
# 115          Denmark      Macedonia           Skopje            1.0
# ...              ...            ...              ...            ...
# 18357         Sweden       Portugal           Lisbon            3.0
# 18450    Netherlands         Rwanda           Kigali            1.0
# 18517         Sweden      Singapore        Singapore           14.0
# 18572         Sweden          Spain           Madrid            1.0
# 18613         Norway    Switzerland             Bern            0.0
#
#        visas_issued  visas_not_issued  visa_refusal_rate
# 6               0.0               0.0                NaN
# 51              0.0               0.0                NaN
# 97              0.0               0.0                NaN
# 99              0.0               0.0                NaN
# 115             0.0               0.0                NaN
# ...             ...               ...                ...
# 18357           0.0               0.0                NaN
# 18450           0.0               0.0                NaN
# 18517           0.0               0.0                NaN
# 18572           0.0               0.0                NaN
# 18613           0.0               0.0                NaN
#
# [788 rows x 7 columns]

# %%
df.describe()
# Out:
#        visas_applied  visas_issued  visas_not_issued  visa_refusal_rate
# count   1.901800e+04  1.901800e+04      19018.000000       18230.000000
# mean    5.118433e+03  4.941748e+03         78.019613           0.023900
# std     2.529766e+04  2.477514e+04        628.178803           0.091372
# min     0.000000e+00  0.000000e+00          0.000000           0.000000
# 25%     2.900000e+01  4.100000e+01          0.000000           0.000000
# 50%     3.920000e+02  3.960000e+02          0.000000           0.000000
# 75%     2.348750e+03  2.163500e+03          0.000000           0.000000
# max     1.030968e+06  1.022443e+06      28329.000000           1.000000
