# %% [markdown]
# Clean-up raw Schengen input file and save as silver statistics

# %%
import schengentools.visastatsparser as vp
job = vp.Parser(2017)
job.extract('../data/bronze/2017-consulates-schengen-visa-stats.xlsx')
job.transform()
job.load()
df = job.df
# Out:
# Input file loaded into dataframe
# Renamed columns
# Removed irrelevant rows such as summary rows
# Selected columns
# Replaced applied, issued and not issued null values with 0
# Calculate refusal rate as the not issued share of the total issued and not issued
# Added column with year issued and not issued
# C:\Users\mogens.hobolth\Miniconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %% [markdown]
# Data quality checks

# %%
df[df["visas_applied"] != df["visas_issued"] + df["visas_not_issued"]]
# Out:
#      schengen_state origin_country   origin_consulate  visas_applied  \
# 0           Austria        ALBANIA             TIRANA           57.0
# 1           Austria        ALGERIA            ALGIERS         2315.0
# 4           Austria     AZERBAIJAN               BAKU         1922.0
# 10          Austria          CHINA            BEIJING        30932.0
# 13          Austria        CROATIA             ZAGREB          271.0
# ...             ...            ...                ...            ...
# 1866    Switzerland            USA        ATLANTA, GA         1405.0
# 1867    Switzerland            USA       NEW YORK, NY         3187.0
# 1868    Switzerland            USA  SAN FRANCISCO, CA         2675.0
# 1869    Switzerland            USA     WASHINGTON, DC         1049.0
# 1870    Switzerland        VIETNAM        HO CHI MINH         3643.0
#
#       visas_issued  visas_not_issued  visa_refusal_rate  year
# 0             47.0               4.0           0.078431  2017
# 1           1658.0             655.0           0.283182  2017
# 4           1737.0             183.0           0.095312  2017
# 10         30309.0             622.0           0.020109  2017
# 13           243.0               7.0           0.028000  2017
# ...            ...               ...                ...   ...
# 1866        1394.0               7.0           0.004996  2017
# 1867        3116.0               9.0           0.002880  2017
# 1868        2662.0               7.0           0.002623  2017
# 1869         993.0              27.0           0.026471  2017
# 1870        3355.0             278.0           0.076521  2017
#
# [1346 rows x 8 columns]

# %%
df[df["visa_refusal_rate"]>1]
# Out:
# Empty DataFrame
# Columns: [schengen_state, origin_country, origin_consulate, visas_applied, visas_issued, visas_not_issued, visa_refusal_rate, year]
# Index: []

# %%
df[df["visa_refusal_rate"].isna()]
# Out:
#      schengen_state               origin_country origin_consulate  \
# 65          Belgium                      AUSTRIA           VIENNA
# 328         Finland                        ITALY             ROME
# 332         Finland                    LITHUANIA          VILNIUS
# 352         Finland                        SPAIN           MADRID
# 1060      Lithuania                      BELGIUM         BRUSSELS
# 1073      Lithuania                       LATVIA             RIGA
# 1122          Malta                      AUSTRIA           VIENNA
# 1226    Netherlands                     SLOVENIA        LJUBLJANA
# 1461       Portugal                       NORWAY             OSLO
# 1477       Portugal                       SWEDEN        STOCKHOLM
